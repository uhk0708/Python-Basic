# %%
# print()는 실행할 때 , 내가 볼 수 있도록 실행화면에 "출력"하는 명령어
# 괄호() 안에 넣어줌

print()

# %%
#변수에 값 할당하기
age,name,is_student = 25 , 'John' , True

#변수 값 출력하기
print('나이:', age)
print('이름:', name)
print('학생 여부:', is_student)
# Out:
# 나이: 25
# 이름: John
# 학생 여부: True

# %%
print("hello , 김현우")
myname = "카리나"
print("hello " + myname + "!")
# Out:
# hello , 김현우
# hello 카리나!

# %% [markdown]
# 문자열

# %%
name , greeting = '현우' , '안녕하세요'

print("이름:",name)
print("인사말:",greeting)
# Out:
# 이름: 현우
# 인사말: 안녕하세요

# %%
# 우리가 사용하는 두 개 이상의 문자가 보이면 >> 문자열이라고 함
# 문자열은 따옴표 안에 문자를 집어 넣음

myname = "김현우"

# %% [markdown]
# 숫자

# %%
age = 25

# %%
# 실수
pi = 3.14
radius = 2.5
area = pi

# %%
# 숫자는 소수점이 없는 것(정수)와 있는 것(소수)로 나뉨

num1 = 10
num2 = 1.2
print(type(num1))
print(type(num2))
print(type(myname))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# 참/거짓 (boolean : bool)

# %%
# 참/거짓
# 참/거짓은 따옴표 없이 첫 글자를 대문자로 사용해요

is_adult = True
is_woman = False
# 이걸 왜 쓰지? 조건무에서 사용됨

# %% [markdown]
# 리스트(list)

# %%
# 리스트는 말 그대로 목록

fruits = ['사과', '배', '강']
# 리스트 안에는 아무거나 들어갈 수 있음 (숫자, 문자, 상관없음)

print(fruits[0]) # index는 0부터 시작함

fruits.append('망고')
print(fruits)
# Out:
# 사과
# ['사과', '배', '강', '망고']

# %%
# 리스트 생성 예시
numbers = [1, 2, 3, 4, 5]
fruits = ["사과", "바나나", "오렌지"]
mixed_list = [1, "사과", True, 3.14]

# 인덱싱과 슬라이싱 예시
print(numbers[0])   # 첫 번째 요소 출력: 1
print(fruits[1])    # 두 번째 요소 출력: "바나나"
print(mixed_list[1:3])  # 두 번째부터 세 번째 요소까지 출력: ["사과", True]

# 요소 추가 예시 (**)
fruits.append("포도")   # "포도"를 리스트에 추가

# 요소 제거 예시
fruits.remove("바나나")  # "바나나"를 리스트에서 제거

# 길이 확인 예시
print(len(fruits))   # 리스트의 길이 출력

# 반복문 예시
for fruit in fruits:
    print(fruit)   # 각 과일 출력
# Out:
# 1
# 바나나
# ['사과', True]
# 3
# 사과
# 오렌지
# 포도

# %% [markdown]
# 딕셔너리(dictionary)

# %%
# 말 그대로 사전 !

a_dict = {} # 빈 딕셔너리 생성(초기화)
print(a_dict)
a_dict = {'name' : '김현우' , 'age' : 25} # 값을 채운 딕셔너리 생성

# a_dict의 값은?
print(a_dict)

# a_dict['name'] 의 값은?
# a_dict['name'] >> key에 접근 , value 값 추출

print(a_dict['name'])
# Out:
# {}
# {'name': '김현우', 'age': 25}
# 김현우

# %%
# 딕셔너리 생성
person = {"이름": "홍길동", "나이": 30, "직업": "개발자"}

# 값에 접근
print(person["이름"])   # "홍길동" 출력

# 요소 추가 및 수정
person["성별"] = "남성"     # 새로운 키-값 쌍 추가
person["나이"] = 31         # 기존 항목의 값 변경

# 요소 제거
del person["직업"]    # "직업" 키-값 쌍 제거

# 키와 값 추출
keys = person.keys()       # 모든 키 추출
values = person.values()   # 모든 값 추출

# 반복문을 통한 키와 값 출력
for key in person:
    print(key, ":", person[key])   # 각 키와 값 출력
# Out:
# 홍길동
# 이름 : 홍길동
# 나이 : 31
# 성별 : 남성

# %%
#문자열 간의 더하기는 두 문자열을 이어붙인 문자열

first_name = "해리"
lask_name = "포터"

print(first_name + " " + lask_name)
#" " :띄어쓰기도 특수 "문자"   특수문자: ! etc..
# Out:
# 해리 포터

# %%
a = '3'
b = '5'

print(a+b)
# Out:
# 35

# %%
'''
a = '3'
b = 5

print(a+b)
TypeError: can only concatenate str (not "int") to str

문자열과 숫자형은 더할 수 없다,
'''
# Out:
# '\na = \'3\'\nb = 5\n\nprint(a+b)\nTypeError: can only concatenate str (not "int") to str\n\n문자열과 숫자형은 더할 수 없다,\n'

# %%
# 위 문제를 해결하기 위해서 숫자 간 더하는 것으로 바꾸자 (문자 >> 숫자)

a = '3'
b = 5

a = int(a)
print(a+b)
# Out:
# 8

# %%
# 그럼 문자열에 숫자를 담은 것은 언제 쓰지?
# 문자와 숫자를 조합하는 경우에 사용

myteam = "drwill"
myid = "55"

mynumber = myteam + myid

print(mynumber)
# Out:
# drwill55

# %% [markdown]
# 특정 문자를 기준으로 문자열 나누기

# %%
# 이메일 주소에서 도메인 'gmail'만 추출하기

myemail = 'test@gamil.com'
print(myemail)
print('-------------------------')
result = (myemail.split ('@'))
print(result[0])
print(result[1])
# Out:
# test@gamil.com
# -------------------------
# test
# gamil.com

# %%
result2 = result[1].split('.')
print(result2)
# Out:
# ['gamil', 'com']

# %%
print(result2[0]) # gamil >> 우리가 알고 싶었던 것 (어떤 이메일 계정 사용하는지 파악)
print(result2 [1]) # com
# Out:
# gamil
# com

# %%
# 한 줄로 한 번에 처리하고파 (method chaining 메서드 체인) << 한번에 가는
myemail.split('@')[1].split('.')[0]
# Out:
# 'gamil'

# %% [markdown]
# 특정 문자를 다른 문자로 바꾸기

# %%
txt = '서울시-마포구-망원동'
print(txt.replace('-', '>'))
# Out:
# 서울시>마포구>망원동

# %% [markdown]
# 질의응답

# %%
'''
저희가 이메일이나 주소를 사용하다 보면 옛날에 co.kr 이런거 쓰던경우가 있었는데 이때 .을 기준으로 분리하면 co 와 kr 도 분리되어 버리는데
이부분은 분리 안되게 할려면 어떻게 해야하나요?
'''
# Out:
# '\n저희가 이메일이나 주소를 사용하다 보면 옛날에 co.kr 이런거 쓰던경우가 있었는데 이때 .을 기준으로 분리하면 co 와 kr 도 분리되어 버리는데 \n이부분은 분리 안되게 할려면 어떻게 해야하나요?\n'

# %%
mail = 'yahoo.co.kr'
a = mail.split('.')
print(a , type(a))


print('-'*50)

b = '.'.join([a[1], a[2]])     # join() 함수는 문자열을 이어붙이는 함수입니다.
print(b, type(b))
# Out:
# ['yahoo', 'co', 'kr'] <class 'list'>
# --------------------------------------------------
# co.kr <class 'str'>

# %%
mail.split('.',maxsplit=1)

# mail 문자열에서 '.' 기준 ,  최대한 옵션(한번)만 분리해 >> 리스트로 변환
# Out:
# ['yahoo', 'co.kr']

# %%
mail.split('.',maxsplit=2)
# Out:
# ['yahoo', 'co', 'kr']

# %% [markdown]
# join()함수

# %%
과일 = ['사과','배','딸기']

'~'.join(과일)
# Out:
# '사과~배~딸기'

# %%
import re
# 정규표현식 (re : regular expresion)

homepage = 'drwill.co.kr'
parts = re.split(r'\.', homepage)[-2:]
# 정규표현식(re)의 split()함수 사용
# r'\.' : '.'을 기준, 문자열 분리
# 그 중 마지막 두 부분을 선택 >> 리스트로 반환


result = ".".join(parts)
print(result)
# Out:
# co.kr

# %%
re.split(r'\.', homepage)
# Out:
# ['drwill', 'co', 'kr']

# %%
k_team =' 조규성, 손흥민, 이강인, 백승호, 황인범, 엄원상, 김민재, 설영우, 김진수, 권경원, 조현우'

print(k_team.split(','))
# Out:
# [' 조규성', ' 손흥민', ' 이강인', ' 백승호', ' 황인범', ' 엄원상', ' 김민재', ' 설영우', ' 김진수', ' 권경원', ' 조현우']

# %%
k_teams = k_team.split(',')

for i , korea in enumerate(k_teams):
  print(f'(i+1) : {korea}')
# Out:
# (i+1) :  조규성
# (i+1) :  손흥민
# (i+1) :  이강인
# (i+1) :  백승호
# (i+1) :  황인범
# (i+1) :  엄원상
# (i+1) :  김민재
# (i+1) :  설영우
# (i+1) :  김진수
# (i+1) :  권경원
# (i+1) :  조현우

# %%
def addprint(a,b):
  print(a+b)

print('the result' , addprint(3,5))
# Out:
# 8
# the result None

# %%
round(1.343434 , 4)
# Out:
# 1.3434
