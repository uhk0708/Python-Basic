# %% [markdown]
# # 새 섹션
# ## 새 섹션

# %% [markdown]
# 무작정 따라하는 파이썬
#
#
# *   멋진 삼행시 짓기_print()실습

# %%
print("저는 자랑스러운 멀캠의 예비 데이터사이언스트입니다.")
print("반갑습니다.")
print("ㅎㅎ")
# Out:
# 저는 자랑스러운 멀캠의 예비 데이터사이언스트입니다.
# 반갑습니다.
# ㅎㅎ

# %% [markdown]
# 기본 자료형

# %%
# 숫자 50과 숫자 50을 더해서 출력하기

print(50+50)
# Out:
# 100

# %%
# 문자열 (string) "50" 과 문자열 (string) "50" 더해서 출력하기

print("50"+"50")
# 문자와 문자 더하면 >> 옆에 붙는다
# Out:
# 5050

# %%
# 파이썬에서 여러 개의 원소(element, 숫자, 문자)를 담는 그릇 >> 리스트(list 목록)
print([50]+[50])
# Out:
# [50, 50]

# %% [markdown]
# 변수
# - 변하는 수

# %%
# 파이썬 변수의 정의
apple = 1
print(apple)
# Out:
# 1

# %%
Apple = '사과'
print(Apple)
# Out:
# 사과

# %%
# 정수와 소수(부동소수점/실수)

a = 1.2
print(a)

b = 2
print(b)

print(a+b)
# Out:
# 1.2
# 2
# 3.2

# %%
# 문자열

가 = 'hello'
print(가)

나 = " good morning"
print(나)
# space (빈 공백)도 문자로 인식

print (가+나)
# Out:
# hello
#  good morning
# hello good morning

# %%
# bool

a - True
print(a)

b = False
print(b)
# Out:
# 1.2
# False

# %%
print(a == b)
# == : 같다
# Out:
# False

# %%
print(a != b)
# != : 다르다
# Out:
# True

# %%
# 추가

# 변수에는 정수, 실수 같은 숫자를 저장할 수 있어요.

num1 = 1
num2 = 2

print(num1 - num2)
# Out:
# -1

# %%
#영어나 한글과 같은 문자도 저장이 가능해요

char = "a"
print(char)
# Out:
# a

# %%
# 이런 문자들의 집합도 리스트로 저장할 수 있네요.
# 리스트 : 여러 원소(element)를 담는 그릇

List_ = [1, 'a' , 'python']
print(List_)
# Out:
# [1, 'a', 'python']

# %%
# 그 목록(List_)에 원소 몇 개있니?

len(List_)
# len : length
# Out:
# 3

# %% [markdown]
# 파이썬 연산자

# %%
# 할당 연산자
a = 1
a = a+1

print (a)
# Out:
# 2

# %%
a = 1

a+=1
# a = a+1
print(a)
# Out:
# 2

# %%
b = 1
b -= 2
# b = b-2

print(b)
# Out:
# -1

# %%
# 산수 연산자

a = 1
b =32
print(a>b)
# True/false 로 반환됨
# Out:
# False

# %%
c = -3  # int(정수)
d = -0.2 # float(소수)

print(c <= d)
# Out:
# True

# %%
a = 1
b = 42

print(a==b)
# Out:
# False

# %%
c = -3  # int(정수)
d = -0.2 # float(소수)

print(c !=d)
# Out:
# True

# %%
# 논리 연산자 (and, or, not)

a = True
b = False

print(a and b)
print(a or b)
print ( not a)
print(not b)
# Out:
# False
# True
# False
# True

# %%
# 멤버 (member, 소속) 연산자 ( in / not in)

a ="사과"
b = ['사과', '배', '참외', '수박', '복숭아']

print (a in b)
# Out:
# True

# %%
c = 'apple'
d = ['Apple', 'pear', 'watermelon', 'peach']

print(c in d)
# 왜? 대소문자 구분
# Out:
# False

# %%
# 식별 인식자(is)

a = '사과'
b = '사과'

print ( a is b) # False
# Out:
# False

# %%
a = 12
b = 12

print(a is b)
# a 는 b 이냐?
# a와 b는 메모리의 동일한 객체 (정수객체 '12' )를 참조하니까
# Out:
# True

# %%
c = 12 # int(정수)
d = 12

print(c is not d)

# c와 d가 다른가요?
# c와 d가 실제로 메모리의 동일한 객체 (정수 객체 '12')를 참조
# >> 동일한 객체
# Out:
# False

# %%
e = 1,2,3
print(e)
print(type(e)) # tuple 상수 - (변하지 않는 수)
# Out:
# (1, 2, 3)
# <class 'tuple'>

# %%
f = [1,2,3]
print(f)
print(type(f)) # list (변할 수 있는)
# Out:
# [1, 2, 3]
# <class 'list'>

# %% [markdown]
# **기타 질의 응답**

# %%
흩따 = 'a'
쌍따 = "a"

print(흩따 == 쌍따)
# Out:
# True

# %%
# is 와 '==' 차이

'''
1. 'is' 와 '==' 동등성 비교
2, '==' 연산자 : 두 객체(a,b,...) 값이 동일한 지 비교
3. 'is' 연산자 : 두 객체(a,b,...) 식별자가 동일한 지 비교
   >> 두 객체 (a,b)가 메모리 상에서 같은 위치있는 지 확인
'''

# %%
a = [1,2,3]
b = [1,2,3]
c = a

# %%
print (a == b) # 값 비교 값은 [1,2,3]
# Out:
# True

# %%
print ( a is b) # a와 b는 값은 같다. 그러나, 서로 다른 메모리 위치에 있음
# Out:
# False

# %%
print(a is c)
# a와 c는 동일한 객체를 참조함
# Out:
# True

# %%
# 추가

# 변수에는 정수, 실수 같은 숫자를 저장할 수 있어요.

num1 = 1
num2 = 2

print(num1 - num2)
# Out:
# -1

# %%
#영어나 한글과 같은 문자도 저장이 가능해요

char = "a"
print(char)
# Out:
# a

# %%
# 이런 문자들의 집합도 리스트로 저장할 수 있네요.
# 리스트 : 여러 원소(element)를 담는 그릇

List_ = [1, 'a' , 'python']
print(List_)
# Out:
# [1, 'a', 'python']

# %%
print(List_)
print(List_[0]) # 숫자 1
print(List_[1]) # 문자열 a
print(List_[2]) # 문자열 python
# print(List_[3]) 에러 발생 indexerror
# Out:
# [1, 'a', 'python']
# 1
# a
# python

# %%
# 그 목록(List_)에 원소 몇 개있니?

len(List_)
# len : length
# Out:
# 3

# %%
# my_var 라는 이름의 변수를 만들고, 원하는 값을 넣어 보아요

my_var_1 = 'a'
my_var_2 = List_

# %%
print(my_var_1 +  my_var_2[2])
# Out:
# apython

# %%
#변수에 문자열로 된 정수와 실수를 저장하면

a = '345' # 문자 >>  정수(int: integer)
b = '3.14' # 문자>> 실수(float)

# %%
print (a)
print(b)
print(type(a)) # 문자 (string)
print(type(b)) # 문자(string)
# Out:
# 345
# 3.14
# <class 'str'>
# <class 'str'>

# %%
a = int(a)
print(type(a))
# Out:
# <class 'int'>

# %%
b =float(b)
print(b)
print(type(b))
# Out:
# 3.0
# <class 'float'>

# %%
b = int(b) # 정수로 변경
print(b)
# Out:
# 3
